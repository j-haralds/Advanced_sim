# %% [markdown]
# # Bayesian Optimization: Searching for the global minima
# **You should hand in a report, via Canvas, maximum 6 pages (excluding references).
# Do not attach any appendices. In the report you should present your data, models and the final results.
# Do not forget to visualize your data and results.
# It is important that you discuss your findings and reflect on the results.
# In addition you need to hand in your Python code.
# The code itself will not be graded, but it should run without errors and upon inspection reproduce the main results you present in the report.
# Emphasis will be put on your ability to use appropriate terminology to describe and discuss the employed statistical methodologies and results.**
#
# **<font color=red>DEADLINE: Dec 10 (Tuesday), 23:59</font>**
#
# ## Background
# In this project you will explore and search the potential energy surface (PES) for an Au atom placed on top of a Au surface.
# We will use a gold surface with Miller indices (433), which is so-called vicinal surface, corresponding to stepped (111) surface.
# The Au atom  placed ontop of the surface is refered to as an ad-atom.
#
# <img src="images/surface_433.png" alt="Drawing" style="width: 850px;"/>
#
# Here the left image shows a side view of the surface with the ad-atom colored in red.
# The right image shows the top view ($z$-direction) of the surface with the primitive cell marked as the smaller rectangle drawn in black.
#
# Finding the position of the ad-atom with the lowest energy is a difficult problem as there are multiple local minima in the PES.
# Furthermore, evaluating the potential energy is commonly done with density functional theory (DFT) which is very computationally expensive and hence it is desirable to keep the number of potential energy calculations as low as possible.
# To tackle these two problems we will employ Bayesian optimization using Gaussian Processes.
#
# Additional information on a very similar task can be found in the [paper by Todorovic *et al.*](https://doi.org/10.1038/s41524-019-0175-2), a copy of which (`Todorovic-2019.pdf` is included in this directory).
#
# ## Atomstic structure
# Here, instead of DFT, we will use an embedded medium theory calculator which is provided in [`ase`](https://wiki.fysik.dtu.dk/ase/index.html) or [`asap`](https://wiki.fysik.dtu.dk/asap).
# You are given a atomistic surface in `structures/surface_supercell.xyz`, which can be read as
# ``` python
# from ase.io import read
# surface = read('structures/surface_supercell.xyz')
# ```
# When searching for the optimal location of the ad-atom we only need to consider positions inside the primitive cell since the PES will be repeating itself if we move outside the primitive cell.
# We therefore only consider position in the domain
# \begin{equation}
# 0 < x < 16.65653 \quad  \land \quad 0 < y < 2.884996
# \end{equation}
#
#
# ## Evaluating the PES
# The ad-atom energy of interest, $E$, is defined as by
# \begin{equation}
# E = E_\text{ad} - E_\text{surface},
# \end{equation}
# where $E_\text{ad}$ is the potential energy of the system with the ad-atom present and $E_\text{surface}$ the energy of just the bare surface system.
# When evaluating the PES, we consider the surface to be completly rigid and only allow the ad-atom to move.
# The energy can thus be written as
# \begin{equation}
# E = E(x,y,z),
# \end{equation}
# where $(x,y,z)$ corresponds to the position of the ad-atom.
# Here, we will allow the $z$-coordinate of the ad-atom to relax to its local minima (given $x$ and $y$) and thus only consider the $x-y$ dependency of the energy, meaning we write the energy $E$ as
# \begin{equation}
# E(x, y) = \min_z E(x, y, z).
# \end{equation}
# The primary goal of this project is to find the global minimum of the function $E(x, y)$ in as few evaluations of $E(x, y)$ as possible.
#
#
# ## Bayesian Optimization
# To this end, we turn to Bayesian optimization using Gaussian processes (GPs).
# The idea is to iteratively train a GP to model the energy, $E(x, y)$, and use it to suggest new possible samples.
#
# Let $\mathbf{X}$ be an array of shape $(N, 2)$ containing $(x, y)$ points as rows and $\boldsymbol{E}$ an array of length $N$ with energies corresponding to $E(x,y)$ for each point in $\mathbf{X}$.
# First we construct an initial model from a few randomly drawn samples $\mathbf{X}$ and their corresponding energies $\boldsymbol{E}$.
# This allows us to train a GP for the given $\mathbf{X}$ and $\boldsymbol{E}$, which provides both an average value $\mu$ and a standard deviation $\sigma$ for the energy at $(x, y)$.
#
# The next step is to select a new point $(x_\text{new},y_\text{new})$ for sampling.
# This is done by finding the point $(x_\text{new},y_\text{new})$ in the domain that maximizes the so-called acquisition function $A(x, y)$.
# In this project, we recommend using the lower confidence  bound (LCB) acquisition function, which is defined as
# \begin{equation}
# A(x, y) = -\mu (x, y) + \beta \sigma (x,y).
# \end{equation}
# Here, $\beta$ is a hyperparameter that can be chosen approximately from the range 1 to 5.
# A large value of $\beta$ will favor more exploration whereas a smaller value will lead to more exploitation.
# * **Exploitation:** Search regions with low mean (low energy)
# * **Exploration:** Search regions with high uncertainty/variance
# You can also adaptively adjust $\beta$ during the Bayesian optimization.
# Can you think of suitable protocols?
#
# A new data point can thus be selected by
# \begin{equation}
# (x_\text{new}, y_\text{new}) = \arg \max_{x, y} A(x, y)
# \end{equation}
# Next the energy at this new point, $E(x_\text{new}, y_\text{new})$, is evaluated and added to our samples $\mathbf{X}$ and $\boldsymbol{E}$.
# This allows a new GP model to be trained and we can iterate through this procedure until convergence is (hopefully) reached.
#
#
# ## GPy optimization
# Setting up your GP model can be achieved using a snippet such as the following
# ```python
# k1 = GPy.kern.RBF(input_dim=2)
# k2 = GPy.kern.Bias(input_dim=2)
# kernel = k1 + k2
# model = GPy.models.GPRegression(x_data, y_data, kernel)
# model.optimize()
# print(model)
# ```
# Where `model.optimize` will find the variance, length scale and bias that maximizes the log-likelihood for the GP.
# The log-likelihood may be very flat or contain multiple local minima.
# In case you end up with strange parameters (such as the lengthscale being $10^{-10}$ or $10^{10}$), it can help to rerun the optimization a few times which can automatically be done via
# ``` python
# model.optimize_restarts()
# ```
# Additionaly, it might help to put some reasonable constraints on the parameters, via
# ```python
# k1 = GPy.kern.RBF(input_dim=2)
# k1['lengthscale'].constrain_bounded(0.1, 5)
# ```
# Instead of strict constraints, one can also set priors over the parameters via, e.g.,
# ``` python
# k1 = GPy.kern.RBF(input_dim=2)
# k1['lengthscale'].set_prior(GPy.priors.Gamma(a=2, b=1))
# ```

# %% [markdown]
# ## Helper function for z-relaxation
# Below is a helper function that you can use to carry out the relaxation over $z$.
# It might be helpful to also define a function only taking $(x, y)$ as argument and setting $z$ to, e.g.,
# ```python
# z = surface.positions[:, 2].max() + 3
# ```
# to make sure the ad-atom sits on top of the surface, and then pass $(x,y,z)$ into `calculate_adatom_energy`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy 
import sklearn
import pandas as pd
import emcee
import ase
import asap3
import GPy
import numpy as np
import random

# LaTeX font
plt.style.use('default')
plt.rc('text', usetex = True)
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['font.family'] = 'serif'
plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath}'
font_size = 16
plt.rcParams['font.size'] = font_size
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.top'] = True
plt.rcParams['ytick.right'] = True

sns.set_palette('deep')
from matplotlib import cbook, cm
from matplotlib.colors import LightSource
# plot in separate window
# %matplotlib inline

rng = np.random.default_rng(seed = 42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[238], line 10
#       8 import asap3
#       9 import GPy
# ---> 10 GPy.util.set_verbosity(False)
#      11 import numpy as np
#      12 import random
#
# AttributeError: module 'GPy.util' has no attribute 'set_verbosity'

# %%
from ase.constraints import FixAtoms, FixedLine
from ase.optimize import BFGS
from ase import Atom
from asap3 import EMT
from ase.calculators.emt import EMT


def calculate_adatom_energy(surface, position):
    """Adds adatom to the input surface configuration at the given position
    and relaxes the ad-atoms z-cooridnate.

    Parameters
    ----------
    bare_surface
        surface configuration without adatom
    position
        position (x, y, z) at which to insert adatom in Ångström

    Returns
    -------
    tuple comprising the energy of the adatom configuration
    """
    # add adatom
    surface_with_adatom = surface.copy()
    surface_with_adatom.append(Atom('Au', position))

    # attach calculator
    calc = EMT()
    surface_with_adatom.calc = calc

    # apply constraints
    constraints = []
    c = FixAtoms(indices=list(range(len(surface_with_adatom) - 1)))
    constraints.append(c)
    c = FixedLine(-1, [0, 0, 1])
    constraints.append(c)

    # relax configuration
    surface_with_adatom.set_constraint(constraints)
    dyn = BFGS(surface_with_adatom, logfile=None)
    dyn.run(fmax=0.02, steps=200)

    energy = surface_with_adatom.get_potential_energy()
    return energy

# %% [markdown]
# ## Setup
# In this project you will need [`ase`](https://wiki.fysik.dtu.dk/ase/index.html), [`asap`](https://wiki.fysik.dtu.dk/asap) and [`GPy`](https://sheffieldml.github.io/GPy/).

# %% [markdown]
# ## Task 1: Analyzing the PES (1.5p)
# The first task of the project will be to generate and visualize the full PES, $E(x, y)$, on a grid for $(x,y)$.
# This will give you access to the global minima by visual inspection and will help with understanding, e.g.,  how the optimization algorithms are working or whether they get stuck in the wrong minimum.
#
# This task may take a few minute to run as it requires a lot of evaluations of the PES.
#
# **Tasks:**
# * Compute the PES, $E(x, y)$, on a dense grid for $x$ and $y$.
# * Visualize the 2D PES as a heatmap.

# %%
from ase.io import read
surface = read('structures/surface_supercell.xyz')

# %%
def get_z_max(surface):
    z = surface.positions[:, 2].max() + 3
    return z

# %%
def grid_gen(xlim, ylim, size=50):
    x = np.linspace(xlim[0], xlim[1], size)
    y = np.linspace(ylim[0], ylim[1], size)
    X, Y = np.meshgrid(x, y)
    return X, Y

# %%
def contour_generator(xlim, ylim, size=50):
    X, Y = grid_gen(xlim, ylim, size)
    Z = np.zeros_like(X)

    for i in range(X.shape[0]):
        for j in range(X.shape[1]):
            Z[i, j] = calculate_adatom_energy(surface,np.hstack(([X[i, j], Y[i, j],get_z_max(surface)])))
    return X, Y, Z

# %%
x_lim = [0,16.65653]
y_lim = [0, 2.884996]

X_contour,Y_contour,E_contour = contour_generator(x_lim , y_lim, size = 50)#, args = [surface, get_z_max(surface)])
# Out:
#  /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_4837/4003490135.py:29: FutureWarning:Please use atoms.calc = calc

# %%
print(np.min(E))
print(true_mini_fun)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(np.min(E))
#       2 print(true_mini_fun)
#
# NameError: name 'E' is not defined

# %%
level = 250
# %matplotlib inline
#plt.contour(X, Y, E, levels=level, alpha=0.25, linewidths=0.25,colors='black')
plt.contourf(X, Y, E, levels=level, cmap='Blues')
plt.xlabel('$x$ [Å]')
plt.ylabel('$y$ [Å]')
plt.colorbar(label='$E(x,y)$ [eV]')
#plt.scatter(true_mini_x,true_mini_y,'rx')
plt.show()

#plt.savefig('figs/adatom_energy_contour.pdf')

# %%
# %matplotlib qt
fig, ax = plt.subplots(subplot_kw=dict(projection = '3d'))
ls = LightSource(1, 1000)


rgb = ls.shade(E, cmap=cm.Blues, vert_exag=0.1, blend_mode='soft')
surf = ax.plot_surface(X, Y, E, rstride=1, cstride=1, facecolors=rgb,
                       linewidth=0, antialiased=False, shade=False)

ax.set_xlabel('$x$ [Å]')
ax.set_ylabel('$y$ [Å]')
ax.set_zlabel('$E(x,y)$ [eV]')
ax.scatter(true_mini_x,true_mini_y,true_mini_fun,'ro')
plt.tight_layout()
#plt.savefig('figs/adatom_energy_surface.pdf')
# Out:
# 2025-12-05 08:44:43.352 Python[977:9377] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-12-05 08:44:43.352 Python[977:9377] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %% [markdown]
# ## Task 2: Local search (3p)
#
# In this task you will try out local search (gradient descent) and see how it succeeds or fails for our function $E(x,y)$.
#
# For the local search consider a random starting position uniformly drawn from the $\{x,y\}$ domain.
#
# **Tasks:**
# * From visual inspection of the PES in Task 1, can you obtain a rough estimate for the percentage of local searches that would end up in the global minimum.
# * Run a few (50-500) local searches and record how many ended up in the global minimum.
#
# *Hint:* `scipy.optimize.minimize` can be used

# %%
def gen_initial_pos(surface,xlim = x_lim,ylim=y_lim):
    x = np.random.uniform(xlim[0], xlim[1])
    y = np.random.uniform(ylim[0], ylim[1])
    z = get_z_max(surface)
    init_pos = np.vstack((x,y,z)).T
    return init_pos.flatten()


def find_minima(N_ints,surface = surface, x_lim = x_lim,y_lim = y_lim):
    results = []
    for i in range(N_ints):
        res = scipy.optimize.minimize(lambda p: calculate_adatom_energy(surface,p), gen_initial_pos(surface),bounds=[x_lim,y_lim,(0,50)])
        results.append({'x_pos':res.x[0],'y_pos':res.x[1],'Energy':res.fun})

    res_df = pd.DataFrame(results)
    return  res_df

# %%
results = []

# %%
res = scipy.optimize.minimize(lambda p: calculate_adatom_energy(surface,p), (3.5,0.75,get_z_max(surface)),bounds=[x_lim,y_lim,(0,50)])
true_mini_x,true_mini_y,_ = res.x
true_mini_fun = res.fun

# %%
print(true_mini_x,true_mini_y)
# Out:
# 3.258763640364864 0.7212496238052966

# %%
# res_df = pd.DataFrame(columns=['x_pos','y_pos','Energy'])

# %%
N_ints = 3

res_df = pd.concat((res_df,find_minima(N_ints)))
# Out:
#  /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_977/4003490135.py:29: FutureWarning:Please use atoms.calc = calc
#  /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_977/432378857.py:3: FutureWarning:The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
print(res_df)
# Out:
#        x_pos     y_pos    Energy
# 0  16.059765  2.163726  7.465567
# 1  16.059705  2.163754  7.465567
# 2  11.916192  0.721246  7.465593

# %%
# %matplotlib inline

plt.contourf(X, Y, E, levels=level, cmap='Blues')
plt.xlabel('$x$ [Å]')
plt.ylabel('$y$ [Å]')
plt.scatter(res_df['x_pos'],res_df['y_pos'],c = res_df['Energy'],cmap='flare')
plt.colorbar(label='$E(x,y)$ [eV]')
plt.plot(true_mini_x,true_mini_y,'rx')

# %%
E_th = 7.076
n_mini = len(res_df['Energy'][res_df['Energy'] < E_th])
frac =  n_mini / len(res_df)
print(f'Percent that reached minimum: {n_mini} of {len(res_df)}' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 E_th = 7.076
# ----> 2 n_mini = len(res_df['Energy'][res_df['Energy'] < E_th])
#       3 frac =  n_mini / len(res_df)
#       4 print(f'Percent that reached minimum: {n_mini} of {len(res_df)}' )
#
# NameError: name 'res_df' is not defined

# %% [markdown]
# ## Task 3: Bayesian optimization (7p)
# Implement your own Bayesian optimization algorithm (using GPy for the Gaussian process part) and run it to find the global minima of $E(x, y)$.
#
# Use the [RBF kernel](https://gpy.readthedocs.io/en/deploy/GPy.kern.src.html#module-GPy.kern.src.rbf) and include a Bias kernel if it is needed.
#
# Suitable $\beta$ values might be in the range 1 to 5.
#
# Start the Bayesian optimization from five (5) randomly drawn samples.
#
#
# **Tasks:**
# * Given the PES in Task 1 choose and motivate priors for the lengthscale and variance parameters in the RBF kernel.
# * Run Bayesian optimization and analyze how the choice of $\beta$ influences convergence. Select a good value for $\beta$.
# * Rerun bayesian optimization with the selected $\beta$. How many iterations are needed until the global minimum is reached?
# * Visualize the PES, the uncertainty ($\sigma$) and the acquisition function together with your samples for the final model.
# * In what regions is the final GP model the most uncertain? Why?
#
#
# *Hints:*
# * If your algorithm gets stuck sampling the same points over and over again, try increasing $\beta$ (more exploration).
# * To find the argmax of $A(x, y)$ you can either evaluate it on a very dense grid or run multiple local searches (starting from random positions) and take the maximum obtained.

# %%
beta = 3.


initial_x = rng.uniform(x_lim[0],x_lim[1],size = 5)
initial_y = rng.uniform(y_lim[0],y_lim[1],size = 5)

initial_samples = np.vstack((initial_x,initial_y,get_z_max(surface)*np.ones_like(initial_y))).T


E_init = []
for i in range(len(initial_samples)):
    E_init = np.append(E_init,calculate_adatom_energy(surface,initial_samples[i]))
print(E_init)
# Out:
#  /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_977/4003490135.py:29: FutureWarning:Please use atoms.calc = calc
# [7.91751525 7.97421488 7.4923947  7.55657616 7.94635828]

# %%
def mean_variance_2_G_alpha_beta(mean,variance):
    alpha = mean**2/variance
    beta = variance/mean
    return alpha, beta

# %%
def get_initial_samples(size = 5,rng = rng,surface = surface, x_lim = x_lim,y_lim = y_lim):
    initial_x = rng.uniform(x_lim[0],x_lim[1],size = size)
    initial_y = rng.uniform(y_lim[0],y_lim[1],size = size)

    X_train_init = np.vstack((initial_x,initial_y)).T

    E_train_init = np.zeros(size)
    for i in range(size):
        E_train_init[i] = calculate_adatom_energy(surface,np.vstack((initial_x[i],initial_y[i],get_z_max(surface))).flatten())
    
    return X_train_init, E_train_init.reshape(-1,1)

def build_model(X_train,E_train,lx_mu_var = [0.5,.1],ly_mu_var = [0.1,.1],sig_mu_var = [0.5,.5]):

    kg = GPy.kern.RBF(input_dim=2,ARD=True)
    a_lx, b_lx = mean_variance_2_G_alpha_beta(lx_mu_var[0],lx_mu_var[1])
    a_ly, b_ly = mean_variance_2_G_alpha_beta(ly_mu_var[0],ly_mu_var[1])
    a_s, b_s = mean_variance_2_G_alpha_beta(sig_mu_var[0],sig_mu_var[1])
    lx_pri = GPy.priors.InverseGamma(a_lx,b_lx)
    ly_pri = GPy.priors.InverseGamma(a_ly,b_ly)
    sig_pri = GPy.priors.InverseGamma(a_s,b_s)

    kg.lengthscale[[0]].set_prior(lx_pri)
    kg.lengthscale[[1]].set_prior(ly_pri)
    kg.variance.set_prior(sig_pri)  
    kb = GPy.kern.Bias(input_dim=2)
    kb.variance.set_prior(GPy.priors.Gamma(a_s,b_s))
    k = kg + kb

    model = GPy.models.GPRegression(X_train,E_train,k)
    return model

def GP(model,X_new):
    gp_mu, gp_cov = model.predict(X_new)
    return gp_mu, gp_cov

def acquisition_function_opt(model,Xp,beta):
    mu, cov = GP(model,Xp)
    a = mu - beta * cov
    return a

def acquisition_function_gen(model,Xp):
    mu, cov = GP(model,Xp)
    a = -cov
    return a, mu

def get_newdata(X_train,E_train,Xp,model,beta,surface = surface,opt = True):
    if opt:
        X_newp = Xp[np.argmin(acquisition_function_opt(model,Xp,beta)),:]
    else:
        X_newp = Xp[np.argmin(acquisition_function_gen(model,Xp)[0]),:]
        E_pred = acquisition_function_gen(model,Xp)[1]
        
    X_new = np.vstack((X_train,X_newp))
    positions = np.vstack((X_newp[0],X_newp[1],get_z_max(surface))).flatten()
    E_newp = calculate_adatom_energy(surface,positions)
    E_new = np.vstack((E_train,E_newp))
    if opt:
        return X_new, E_new
    else:
        return X_new, E_new, E_pred

# %%
from tqdm import tqdm

def run_GP(beta,rng= rng,surface = surface, size = 5,alpha = [1,1], E_th = E_th,
           X_contour = X_contour, Y_contour = Y_contour):
    pbar = tqdm(desc='Processing')
    X_train, E_train = get_initial_samples(size = size,rng = rng,surface = surface)
    #Xp = np.vstack((np.linspace(x_lim[0],x_lim[1],n_preds).flatten(),np.linspace(y_lim[0],y_lim[1],n_preds).flatten())).T
    Xp = np.vstack((X_contour.flatten(),Y_contour.flatten())).T
    n = 0
    res_min = []
    res_all = []
    for i in range(len(X_train)):
        res_all.append({'x_pos':X_train[i,0],'y_pos':X_train[i,1],'Energy':E_train[i]}) 
        
    while np.abs(np.min(E_train)) > E_th:
        model = build_model(X_train,E_train)
        X_train, E_train = get_newdata(X_train,E_train,Xp,model,beta)
        n += 1
        min_i = np.argmin(E_train)
        res_min.append({'x_pos':X_train[min_i,0],'y_pos':X_train[min_i,1],'Energy':E_train[min_i]})
        res_all.append({'x_pos':X_train[-1,0],'y_pos':X_train[-1,1],'Energy':E_train[-1]})
        if n > 250:
            print(f'{np.min(E_train)} eV at {X_train[np.argmin(E_train),:]}')
            break
        pbar.update(1)
    pbar.close()
    return pd.DataFrame(res_min), pd.DataFrame(res_all), model

# %%
betas = np.arange(1,11,1)
plt.figure(figsize=(12,8))
for b in betas:
    min_df_b, model_b, all_df_b = run_GP(b)
    plt.plot(min_df_b['Energy'],color=cm.coolwarm(b/10),label = f'$\\beta = {b}\\Rightarrow {np.min(min_df_b['Energy'])[0]:.3f}$')    


plt.xlabel('Iteration')
plt.ylabel('Minimum Energy [eV]')
plt.legend()
# Out:
#  /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_4837/4003490135.py:29: FutureWarning:Please use atoms.calc = calc
# Processing: 250it [00:40,  6.19it/s]
# 7.111902017808753 eV at [3.44617862 0.79586097]
# Processing: 250it [00:38,  6.56it/s]
# 7.1067983588943 eV at [3.44617862 0.69637834]
# Processing: 250it [00:42,  5.90it/s]
# 7.1067983588943 eV at [3.44617862 0.69637834]
# Processing: 250it [00:40,  6.12it/s]
# 7.111902017808753 eV at [3.44617862 0.79586097]
# Processing: 250it [00:43,  5.80it/s]
# 7.111902017808753 eV at [3.44617862 0.79586097]
# Processing: 250it [00:41,  5.96it/s]
# 7.111902017808753 eV at [3.44617862 0.79586097]
# Processing: 250it [00:41,  6.00it/s]
# 7.136223773472043 eV at [3.44617862 0.89534359]
# Processing: 250it [00:41,  6.07it/s]
# 7.136223773472043 eV at [3.44617862 0.89534359]
# Processing: 250it [00:50,  4.97it/s]
# 7.136223773472043 eV at [3.44617862 0.89534359]
# Processing: 250it [00:49,  5.04it/s]
# 7.111902017808753 eV at [3.44617862 0.79586097]

# %%
def GP_plot(df_min,df_all,model,X_contour = X_contour,Y_contour = Y_contour,E_contour = E_contour,level = 250):
    fig, ax = plt.subplots(1,2, figsize=(12, 5),sharey=True)
    
    ax[0].contourf(X_contour, Y_contour, E_contour, levels=level, cmap='Blues')
    ax[0].set_xlabel('$x$ [Å]')
    ax[0].set_ylabel('$y$ [Å]')
    ax[0].plot(df_min['x_pos'],df_min['y_pos'],'-o',color = 'tab:red',label = 'Sampled positions')
    ax[0].set_title('True $E(x,y)$')
    Xp = np.vstack((X_contour.flatten(),Y_contour.flatten())).T
    gp_mu, gp_cov = GP(model, Xp)
    E_gp = gp_mu.reshape(X_contour.shape)

    ax[1].contourf(X_contour, Y_contour, E_gp, levels=level, cmap='Reds')
    ax[1].plot(df_all['x_pos'],df_all['y_pos'],'o',color = 'tab:blue',label = 'Sampled positions',alpha=0.75)
    ax[1].plot(df_all['x_pos'][:5],df_all['y_pos'][:5],'x',color = 'black',label = 'Sampled positions',markersize=10)
    ax[1].set_title('Emulated $E(x,y)$')
    ax[1].set_xlabel('$x$ [Å]')
    fig.subplots_adjust(wspace=0)

# %%
min_df,all_df,model = run_GP(2.5)
# Out:
# Processing: 0it [00:00, ?it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 1it [00:00,  1.18it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 2it [00:01,  2.25it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 3it [00:01,  3.15it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 4it [00:01,  3.90it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 5it [00:01,  4.49it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 6it [00:01,  4.87it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 7it [00:01,  5.18it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 8it [00:01,  5.55it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 9it [00:02,  5.41it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 10it [00:02,  5.42it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 11it [00:02,  5.03it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 12it [00:02,  4.45it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 13it [00:03,  4.93it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 14it [00:03,  5.28it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 15it [00:03,  5.32it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 16it [00:03,  5.28it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 17it [00:03,  4.94it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 19it [00:04,  5.98it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 20it [00:04,  5.53it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 21it [00:04,  5.90it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 22it [00:04,  5.66it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 23it [00:04,  5.75it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 25it [00:05,  6.82it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 26it [00:05,  6.44it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 27it [00:05,  6.18it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 28it [00:05,  6.32it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 29it [00:05,  6.10it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 30it [00:05,  6.12it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 31it [00:06,  6.34it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 32it [00:06,  6.45it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 33it [00:06,  5.78it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 34it [00:06,  5.41it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 35it [00:06,  4.86it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 36it [00:06,  5.38it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 37it [00:07,  5.65it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 38it [00:07,  6.10it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 39it [00:07,  6.16it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 40it [00:07,  5.93it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 41it [00:07,  6.20it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 42it [00:07,  5.73it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 43it [00:08,  5.81it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 44it [00:08,  6.12it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 45it [00:08,  5.75it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 46it [00:08,  5.71it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 47it [00:08,  5.66it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 48it [00:09,  5.65it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 49it [00:09,  6.04it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 50it [00:09,  6.17it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 51it [00:09,  6.21it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 52it [00:09,  6.03it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 53it [00:09,  5.84it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 54it [00:09,  5.96it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 55it [00:10,  6.21it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 56it [00:10,  6.14it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 57it [00:10,  6.29it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 58it [00:10,  5.52it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 59it [00:10,  5.67it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 60it [00:11,  5.53it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 61it [00:11,  5.07it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 62it [00:11,  5.33it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 63it [00:11,  4.93it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 64it [00:11,  4.96it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 65it [00:12,  5.46it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 66it [00:12,  5.45it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 67it [00:12,  5.57it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 68it [00:12,  5.49it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 69it [00:12,  5.30it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 70it [00:12,  5.03it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 71it [00:13,  5.21it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 72it [00:13,  5.47it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 73it [00:13,  5.56it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 74it [00:13,  5.67it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 75it [00:13,  5.59it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 76it [00:13,  5.83it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 77it [00:14,  6.08it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 78it [00:14,  6.11it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 79it [00:14,  5.94it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 80it [00:14,  6.27it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 81it [00:14,  6.31it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 82it [00:15,  5.44it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 83it [00:15,  5.86it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 84it [00:15,  5.36it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 85it [00:15,  5.69it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 86it [00:15,  5.87it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 87it [00:15,  5.97it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 88it [00:16,  5.83it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 89it [00:16,  5.62it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 90it [00:16,  5.83it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 91it [00:16,  5.77it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 92it [00:16,  5.93it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 93it [00:16,  5.92it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 94it [00:17,  5.43it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 95it [00:17,  5.66it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 96it [00:17,  6.07it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 97it [00:17,  5.37it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 98it [00:17,  5.43it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 100it [00:18,  6.60it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 101it [00:18,  6.84it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 102it [00:18,  6.30it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 103it [00:18,  5.72it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 104it [00:18,  5.06it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 105it [00:19,  5.15it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 106it [00:19,  5.84it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 107it [00:19,  5.83it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 108it [00:19,  5.97it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 109it [00:19,  5.98it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 110it [00:19,  5.18it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 111it [00:20,  5.41it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 112it [00:20,  5.74it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 113it [00:20,  5.94it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 114it [00:20,  5.92it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 115it [00:20,  6.42it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 116it [00:20,  5.71it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 117it [00:21,  5.75it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 118it [00:21,  6.01it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 119it [00:21,  6.29it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 120it [00:21,  6.18it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 121it [00:21,  6.07it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 122it [00:21,  5.76it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 123it [00:22,  5.72it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 124it [00:22,  5.58it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 125it [00:22,  5.55it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 126it [00:22,  5.20it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 127it [00:22,  5.46it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 128it [00:23,  5.01it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 129it [00:23,  4.85it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 130it [00:23,  5.17it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 132it [00:23,  6.29it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 133it [00:23,  5.97it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 134it [00:24,  5.46it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 135it [00:24,  5.96it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 136it [00:24,  5.63it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 137it [00:24,  5.84it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 138it [00:24,  5.77it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 139it [00:24,  5.71it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 140it [00:25,  5.63it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 141it [00:25,  5.37it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 142it [00:25,  5.29it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 143it [00:25,  5.88it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 144it [00:25,  5.84it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 145it [00:25,  5.93it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 146it [00:26,  5.93it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 147it [00:26,  5.89it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 148it [00:26,  5.62it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 149it [00:26,  6.07it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 150it [00:26,  5.45it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 151it [00:27,  5.71it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 152it [00:27,  5.55it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 153it [00:27,  5.37it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 154it [00:27,  5.19it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 155it [00:27,  5.35it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 156it [00:28,  5.23it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 157it [00:28,  5.59it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 158it [00:28,  5.87it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 159it [00:28,  5.87it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 160it [00:28,  5.68it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 161it [00:28,  5.28it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 162it [00:29,  5.68it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 163it [00:29,  5.71it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 164it [00:29,  5.62it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 165it [00:29,  5.69it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 166it [00:29,  5.51it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 167it [00:29,  5.33it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 168it [00:30,  5.47it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 169it [00:30,  5.66it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 170it [00:30,  5.53it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 171it [00:30,  5.66it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 172it [00:30,  6.02it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 173it [00:31,  5.47it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 174it [00:31,  5.05it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 175it [00:31,  5.07it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 176it [00:31,  5.41it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 177it [00:31,  5.64it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 178it [00:31,  5.99it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 179it [00:32,  6.28it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 180it [00:32,  6.62it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 181it [00:32,  6.32it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 182it [00:32,  6.02it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 183it [00:32,  6.31it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 184it [00:32,  6.02it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 185it [00:33,  6.21it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 186it [00:33,  6.06it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 187it [00:33,  5.95it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 188it [00:33,  6.27it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 189it [00:33,  5.86it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 190it [00:33,  5.94it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 191it [00:34,  5.46it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 192it [00:34,  5.66it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 193it [00:34,  5.62it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 194it [00:34,  5.56it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 195it [00:34,  5.67it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 196it [00:34,  5.73it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 197it [00:35,  5.70it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 198it [00:35,  5.47it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 199it [00:35,  5.80it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 200it [00:35,  5.93it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 201it [00:35,  5.82it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 202it [00:35,  5.78it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 203it [00:36,  5.77it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 204it [00:36,  5.26it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 205it [00:36,  5.40it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 206it [00:36,  4.60it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 207it [00:37,  4.93it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 208it [00:37,  5.30it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 209it [00:37,  4.08it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 210it [00:37,  4.53it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 211it [00:37,  4.68it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 212it [00:38,  4.66it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 213it [00:38,  5.21it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 214it [00:38,  5.34it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 215it [00:38,  5.07it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 216it [00:38,  4.75it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 217it [00:39,  4.57it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 218it [00:39,  4.69it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 219it [00:39,  4.77it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 220it [00:39,  4.58it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 221it [00:39,  4.86it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 222it [00:40,  4.09it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 223it [00:40,  4.25it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 224it [00:40,  3.52it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 225it [00:41,  3.89it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 226it [00:41,  4.36it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 227it [00:41,  4.71it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 228it [00:41,  4.99it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 229it [00:41,  4.56it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 230it [00:42,  4.10it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 231it [00:42,  4.28it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 232it [00:42,  4.42it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 233it [00:42,  4.43it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 234it [00:42,  4.82it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 235it [00:43,  3.01it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 236it [00:43,  3.34it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 237it [00:44,  3.77it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 238it [00:44,  3.72it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 239it [00:44,  4.12it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 240it [00:44,  4.52it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 241it [00:44,  4.80it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 242it [00:44,  5.09it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 243it [00:45,  4.97it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 244it [00:45,  5.10it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 245it [00:45,  5.23it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 246it [00:45,  5.05it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 247it [00:45,  5.34it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 248it [00:46,  5.07it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 249it [00:46,  5.14it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 250it [00:46,  4.84it/s]reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 250it [00:46,  5.34it/s]
# 7.0944175524981485 eV at [3.39929184 0.70652963]

# %%
GP_plot(min_df,all_df,model)
print(f'Minimum found at {np.min(min_df['Energy'])[0]} eV')
# Out:
# Minimum found at 7.0944175524981485 eV

# %%
fig, ax = plt.subplots(1,2, figsize=(8,3))
ax[0].hist(all_df['x_pos'],bins=25)
ax[1].hist(all_df['y_pos'],bins=25,orientation='horizontal')
# Out:
# (array([ 52.,   0.,   0.,   0.,   0.,   6., 313.,  20.,  12.,   9.,   5.,
#           3.,   5.,   0.,   7.,   3.,  13.,   7.,   2.,   0.,   0.,   1.,
#           0.,   0.,  48.]),
#  array([0.        , 0.11539984, 0.23079968, 0.34619952, 0.46159936,
#         0.5769992 , 0.69239904, 0.80779888, 0.92319872, 1.03859856,
#         1.1539984 , 1.26939824, 1.38479808, 1.50019792, 1.61559776,
#         1.7309976 , 1.84639744, 1.96179728, 2.07719712, 2.19259696,
#         2.3079968 , 2.42339664, 2.53879648, 2.65419632, 2.76959616,
#         2.884996  ]),
#  <BarContainer object of 25 artists>)

# %% [markdown]
# ## Task 4: Transition paths barriers (4.5p)
# In Bayesian optimization the low energy regions of the parameter space $(x, y)$ are of interest and thus get sampled more by the acquisition function.
# Next we look at using GPs as a general purpose potential/model for the full PES.
# In principle once one has a fast and accurate model over the entire PES we could compute various properties of the ad-atom, such as diffusion barriers and thermodynamic properties.
#
# Here you will look at the energy landscape along a linear path between the global minima and the local energy minimum around $(11, 2.1)$.
# To construct the linear path from the initial state to the final state we can write
# \begin{equation}
# (x, y) = (x_{start}, y_{start}) + \lambda ( x_{end} -x_{start}, y_{end}-y_{start})
# \end{equation}
# where $\lambda$ should be varied between $0 \to 1$ to span the path.
#
# In this task you will construct a general purpose GP to model the PES and compute the energy along the transition path described above.
# This may require 100 to 200 or more training samples.
# Use $(x_\text{start}, y_\text{start})$ and $(x_\text{end}, y_\text{end})$ plus a few random samples as a starting point and then iterativley construct a GP model using a suitable acquisition function.
#
# **Tasks:**
# * Train a general purpose GP model.
# * Compute the error (e.g., [RMSE](https://en.wikipedia.org/wiki/Root-mean-square_deviation)) of the model evaluated over the entire PES using data from Task 1 as a function of training samples. How many samples are needed to get a "good" model in your opinion?
# * Use the GP model to compute the energy and its uncertainty along the linear path between the initial and final state. Compare with the GP model obtained in Task 3, and compare with the correct energy along the path computed with EMT. Discuss your findings.
#
#
# *Hint:* To train a general purpose model one can use the LCB acquisition function and let $\beta \to \infty$.

# %%
def line(lam,x0 = true_mini_x,y0 = true_mini_y,x1 = 11,y1 = 2.1):
    x = x0 + lam * (x1 - x0)
    y = y0 + lam * (y1 - y0)
    return x,y


def E_line(lam,surface = surface):
    x,y = line(lam)
    pos = np.vstack((x,y,np.ones_like(x)*get_z_max(surface))).T
    E_line = np.zeros(len(lam))
    for i in range(len(lam)):
        E_line[i] = calculate_adatom_energy(surface,pos[i,:].flatten())
    return E_line.flatten()


lam = np.linspace(0,1,50)

plt.plot(lam,E_line(lam))
# Out:
# (50,)
# (50,)

# %%
def run_gen_GP(rng= rng,surface = surface, size = 5,alpha = [1,1], E_th = E_th,
           X_contour = X_contour, Y_contour = Y_contour,E_contour = E_contour):
    pbar = tqdm(desc='Processing')
    X_train, E_train = get_initial_samples(size = size,rng = rng,surface = surface)
    #Xp = np.vstack((np.linspace(x_lim[0],x_lim[1],n_preds).flatten(),np.linspace(y_lim[0],y_lim[1],n_preds).flatten())).T
    Xp = np.vstack((X_contour.flatten(),Y_contour.flatten())).T
    n = 0

    res_all = []
    for i in range(len(X_train)):
        res_all.append({'x_pos':X_train[i,0],'y_pos':X_train[i,1],'Energy':E_train[i],'rmse':0}) 
    while np.abs(np.min(E_train)) > E_th:
        model = build_model(X_train,E_train)
        X_train, E_train,E_pred = get_newdata(X_train,E_train,Xp,model, beta = 0,opt = False)
        n += 1
        rmse = np.sqrt(np.mean((E_pred - E_contour.ravel())**2))
        res_all.append({'x_pos':X_train[-1,0],'y_pos':X_train[-1,1],'Energy':E_train[-1],'rmse':rmse})
        if n > 250:
            print(f'{np.min(E_train)} eV at {X_train[np.argmin(E_train),:]}')
            break
        pbar.update(1)
    pbar.close()
    return pd.DataFrame(res_all), model

# %%
df_gen,model = run_gen_GP()
# Out:
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
#
#
#
#
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.lengthscale
# reconstraining parameters rbf.variance
# reconstraining parameters bias.variance
# Processing: 250it [00:59,  4.23it/s]
# 7.230784677247962 eV at [3.39929184 1.11867192]

# %%
GP_plot(min_df,df_gen,model)

# %%
plt.plot(np.arange(0,len(df_gen['rmse'][5:]),1)+5,df_gen['rmse'][5:],'-o')
plt.xlabel('Number of training points')
plt.ylabel('RMSE [eV]')
# Out:
# Text(0, 0.5, 'RMSE [eV]')

# %%
mu,cov = GP(model,np.vstack((line(lam))).T)

mu = mu.flatten()
cov = np.diag(cov.ravel())

fun_mean = []
for i in range(10):
    fun = scipy.stats.multivariate_normal.rvs(mean=mu, cov=cov,random_state=rng)
    fun_mean.append(fun)
    plt.plot(lam,fun,'--')
fun_mean = np.mean(np.vstack(fun_mean),axis=0)
plt.plot(lam,fun_mean,'-',color = 'tab:orange',lw = 3,label = 'Mean prediction')
plt.plot(lam,E_line(lam),'-',color = 'tab:red',lw = 3)
